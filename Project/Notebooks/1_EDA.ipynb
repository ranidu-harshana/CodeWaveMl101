# %% [markdown]
# ## Dataset Loading and Basic Exploration

# %% [markdown]
# ### importing necessary libraries

# %%
# importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Unzipping the dataset

# %%
! unzip ../Data/archive.zip -d ../Data/
# Out:
# Archive:  ../Data/archive.zip
#   inflating: ../Data//customer_churn_dataset-testing-master.csv
#   inflating: ../Data//customer_churn_dataset-training-master.csv

# %%
dataset  = pd.read_csv('../Data/customer_churn_dataset-training-master.csv')

# %%
# simple peek at the dataset

dataset.head()
# Out:
#    CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0         2.0  30.0  Female    39.0             14.0            5.0
# 1         3.0  65.0  Female    49.0              1.0           10.0
# 2         4.0  55.0  Female    14.0              4.0            6.0
# 3         5.0  58.0    Male    38.0             21.0            7.0
# 4         6.0  23.0    Male    32.0             20.0            5.0
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0           18.0          Standard          Annual        932.0
# 1            8.0             Basic         Monthly        557.0
# 2           18.0             Basic       Quarterly        185.0
# 3            7.0          Standard         Monthly        396.0
# 4            8.0             Basic         Monthly        617.0
#
#    Last Interaction  Churn
# 0              17.0    1.0
# 1               6.0    1.0
# 2               3.0    1.0
# 3              29.0    1.0
# 4              20.0    1.0

# %% [markdown]
# ## EDA

# %% [markdown]
# * CustomerID: A unique identifier for each customer
# * Gender: Gender of the customer
# * Age: The age of the customer
# * Tenure: Duration in months for which a customer has been using the company's products or services
# * Usage Frequency: Number of times that the customer has used the company’s services in the last month
# * Support Calls: Number of calls that the customer has made to the customer support in the last month
# * Payment Delay: Number of days that the customer has delayed their payment in the last month
# * Subscription Type: Type of subscription the customer has choosen
# * Contract Length: Duration of the contract that the customer has signed with the company
# * Total Spend: Total amount of money the customer has spent on the company's products or services
# * Last Interaction: Number of days since the last interaction that the customer had with the company
# * Churn: Binary label indicating whether a customer has churned (1) or not (0)

# %%
## looking at each coilumns data types and null value counts
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440833 entries, 0 to 440832
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CustomerID         440832 non-null  float64
#  1   Age                440832 non-null  float64
#  2   Gender             440832 non-null  object
#  3   Tenure             440832 non-null  float64
#  4   Usage Frequency    440832 non-null  float64
#  5   Support Calls      440832 non-null  float64
#  6   Payment Delay      440832 non-null  float64
#  7   Subscription Type  440832 non-null  object
#  8   Contract Length    440832 non-null  object
#  9   Total Spend        440832 non-null  float64
#  10  Last Interaction   440832 non-null  float64
#  11  Churn              440832 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 40.4+ MB

# %%
dataset.describe()
# Out:
#           CustomerID            Age         Tenure  Usage Frequency  \
# count  440832.000000  440832.000000  440832.000000    440832.000000
# mean   225398.667955      39.373153      31.256336        15.807494
# std    129531.918550      12.442369      17.255727         8.586242
# min         2.000000      18.000000       1.000000         1.000000
# 25%    113621.750000      29.000000      16.000000         9.000000
# 50%    226125.500000      39.000000      32.000000        16.000000
# 75%    337739.250000      48.000000      46.000000        23.000000
# max    449999.000000      65.000000      60.000000        30.000000
#
#        Support Calls  Payment Delay    Total Spend  Last Interaction  \
# count  440832.000000  440832.000000  440832.000000     440832.000000
# mean        3.604437      12.965722     631.616223         14.480868
# std         3.070218       8.258063     240.803001          8.596208
# min         0.000000       0.000000     100.000000          1.000000
# ...

# %%
# EDA - Univariate Analysis - Report .PDF

# %% [markdown]
# ## Univariate Analysis

# %%
# Univariate Analysis for age

## Draw a histogram for age
plt.figure(figsize=(10,6))
sns.histplot(data=dataset, x='Age', bins=30, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
## Draw a violon plot for age
plt.figure(figsize=(8,6))
sns.violinplot(y=dataset['Age'])
plt.title('Age Violin Plot')
plt.ylabel('Age')
plt.show()

# %%
# KDE Plot for Age

plt.figure(figsize=(10,6))
sns.kdeplot(data=dataset, x='Age', fill=True)
plt.title('Age KDE Plot')
plt.xlabel('Age')
plt.ylabel('Density')
plt.show()

# %%
# Box plot for Age  
plt.figure(figsize=(8,6))
sns.boxplot(y=dataset['Age'])
plt.title('Age Box Plot')
plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %%
# Tenure Univariate Analysis

# Draw a histogram for Tenure
plt.figure(figsize=(10,6))
sns.histplot(data=dataset, x='Tenure', bins=30, kde=True)
plt.title('Tenure Distribution')
plt.xlabel('Tenure (months)')
plt.ylabel('Frequency')
plt.show()

# %%
# Violin plot for Tenure
plt.figure(figsize=(8,6))
sns.violinplot(y=dataset['Tenure'])     
plt.title('Tenure Violin Plot')
plt.ylabel('Tenure (months)')
plt.show()

# %%
## Usage frequency analysis

plt.figure(figsize=(10,6))
sns.histplot(data=dataset, x='Usage Frequency', bins=30, kde=True)
plt.title('Usage Frequency Distribution')
plt.xlabel('Usage Frequency')
plt.ylabel('Frequency')
plt.show()

# %%
## Support calls analysis   
plt.figure(figsize=(10,6))
sns.histplot(data=dataset, x='Support Calls', bins=10)
plt.title('Support Calls Distribution')
plt.xlabel('Number of Support Calls')
plt.ylabel('Frequency')
plt.show()

# %%
## violin plot for Support Calls    
plt.figure(figsize=(8,6))
sns.violinplot(y=dataset['Support Calls'])
plt.title('Support Calls Violin Plot')
plt.ylabel('Number of Support Calls')
plt.show()

# %%
## Categorical Feature Analysis

# Gender

# Bar chart for gender distribution
plt.figure(figsize=(8,6))
sns.countplot(data=dataset, x='Gender')
plt.title('Gender Distribution')        
plt.show()

# %%
## pie chart for Gender

gender_counts = dataset['Gender'].value_counts()
plt.figure(figsize=(8,6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Gender Distribution')
plt.axis('equal')
plt.show()

# %%
## Subscription Type Analysis

# Bar chart for subscription type distribution
plt.figure(figsize=(8,6))
sns.countplot(data=dataset, x='Subscription Type')
plt.title('Subscription Type Distribution')
plt.show()

# %%
# pie chart for Subscription Type
subscription_counts = dataset['Subscription Type'].value_counts()
plt.figure(figsize=(8,6))
plt.pie(subscription_counts, labels=subscription_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Subscription Type Distribution')
plt.axis('equal')
plt.show()

# %%
## Churn Analysis

# Bar chart for churn distribution map 1 to "Churn" and 0 to "No Churn"
plt.figure(figsize=(8,6))
sns.countplot(data=dataset, x='Churn')
plt.title('Churn Distribution')
plt.xticks(ticks=[0, 1], labels=['No Churn', 'Churn'])
plt.show()

# pie chart for Churn
churn_counts = dataset['Churn'].value_counts()
plt.figure(figsize=(8,6))
plt.pie(churn_counts, labels=churn_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Churn Distribution')
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
##  Churn variable based bivariate analysis

## Relationship between Gender and Churn

## Question: Is there a significant difference in churn rates between male and female customers?

# mapping 0 to "No Churn" and 1 to "Churn" for better visualization
dataset['Churn_Mapped'] = dataset['Churn'].map({0: 'No Churn', 1: 'Churn'})
plt.figure(figsize=(8,6))
sns.countplot(data=dataset, x='Gender', hue='Churn_Mapped')
plt.title('Gender vs Churn')
plt.show()

# %%
## Relationship between Support Calls and Churn
## Question: Do customers who make more support calls have a higher likelihood of churning?     
plt.figure(figsize=(10,6))
sns.boxplot(x='Churn_Mapped', y='Support Calls', data=dataset)
plt.title('Support Calls vs Churn')
plt.xlabel('Churn Status')
plt.ylabel('Number of Support Calls')
plt.show()

# %%
# bar chart for support calls vs churn
plt.figure(figsize=(10,6))
sns.barplot(x='Churn_Mapped', y='Support Calls', data=dataset,      ci=None)    
plt.title('Average Support Calls by Churn Status')
plt.xlabel('Churn Status')
plt.ylabel('Average Number of Support Calls')
plt.show()
# Out:
# /var/folders/d0/ccl21f3n4w371s4wkd1jgkqw0000gn/T/ipykernel_4892/385863500.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Churn_Mapped', y='Support Calls', data=dataset,      ci=None)

# %%
### Age vs Churn Analysis

plt.figure(figsize=(10,6))
sns.boxplot(x='Churn_Mapped', y='Age', data=dataset)
plt.title('Age vs Churn')
plt.xlabel('Churn Status')
plt.ylabel('Age')
plt.show()

# %%
## Dividing ages into groups to see churn rates across different age brackets
age_bins = [18, 25, 35, 45, 55, 65, 100]
age_labels = ['18-24', '25-34', '35-44', '45-54', '55-64', '65+']
dataset['Age_Group'] = pd.cut(dataset['Age'], bins=age_bins, labels=age_labels, right=False)    

## visulalizing churne rates across age groups
plt.figure(figsize=(10,6))
sns.countplot(data=dataset, x='Age_Group', hue='Churn_Mapped')
plt.title('Age Group vs Churn')
plt.xlabel('Age Group')
plt.ylabel('Number of Customers')
plt.show()

# %%
## Churn based on Subscription Type
plt.figure(figsize=(10,6))
sns.countplot(data=dataset, x='Subscription Type', hue='Churn_Mapped')
plt.title('Subscription Type vs Churn')     
plt.show()

# %%
## Contract Length vs Churn Analysis # legend to devide churened and non churned

## Churned and non churned customers based on contract length
plt.figure(figsize=(10,6))
sns.countplot(data=dataset, x='Contract Length', hue='Churn_Mapped')
plt.title('Contract Length vs Churn')
plt.xlabel('Contract Length (months)')
plt.ylabel('Number of Customers')
plt.show()

# %%
## Assignment : Complete report on EDA

# %% [markdown]
# # Data Preprocessing

# %%
dataset.head()
# Out:
#    CustomerID   Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0         2.0  30.0  Female    39.0             14.0            5.0
# 1         3.0  65.0  Female    49.0              1.0           10.0
# 2         4.0  55.0  Female    14.0              4.0            6.0
# 3         5.0  58.0    Male    38.0             21.0            7.0
# 4         6.0  23.0    Male    32.0             20.0            5.0
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0           18.0          Standard          Annual        932.0
# 1            8.0             Basic         Monthly        557.0
# 2           18.0             Basic       Quarterly        185.0
# 3            7.0          Standard         Monthly        396.0
# 4            8.0             Basic         Monthly        617.0
#
#    Last Interaction  Churn Churn_Mapped Age_Group
# 0              17.0    1.0        Churn     25-34
# 1               6.0    1.0        Churn       65+
# ...

# %%
# One hot encoding - One hot encoding is a technique used to represent categorical variables as binary vectors.
# ordinal encoding - ordinal categorical variables are those that have a clear ordering or ranking.


# one hot encoding columns gender and contract length # convert to ones and zeros   

dataset = pd.get_dummies(dataset, columns=['Gender', 'Contract Length'])

# %%
dataset.head()
# Out:
#    CustomerID   Age  Tenure  Usage Frequency  Support Calls  Payment Delay  \
# 0         2.0  30.0    39.0             14.0            5.0           18.0
# 1         3.0  65.0    49.0              1.0           10.0            8.0
# 2         4.0  55.0    14.0              4.0            6.0           18.0
# 3         5.0  58.0    38.0             21.0            7.0            7.0
# 4         6.0  23.0    32.0             20.0            5.0            8.0
#
#   Subscription Type  Total Spend  Last Interaction  Churn Churn_Mapped  \
# 0          Standard        932.0              17.0    1.0        Churn
# 1             Basic        557.0               6.0    1.0        Churn
# 2             Basic        185.0               3.0    1.0        Churn
# 3          Standard        396.0              29.0    1.0        Churn
# 4             Basic        617.0              20.0    1.0        Churn
#
#   Age_Group  Gender_Female  Gender_Male  Contract Length_Annual  \
# ...

# %%
one_hot_cols = [col for col in dataset.columns if col.startswith('Gender_') or col.startswith('Contract Length_')]
dataset[one_hot_cols] = dataset[one_hot_cols].astype(int)

# %%
# ordinal encoding for Subscription Type
subscription_type_mapping = {
    'Basic': 1,
    'Standard': 2,
    'Premium': 3
}   
dataset['Subscription Type_Encoded'] = dataset['Subscription Type'].map(subscription_type_mapping)

# %%
dataset.head()
# Out:
#    CustomerID   Age  Tenure  Usage Frequency  Support Calls  Payment Delay  \
# 0         2.0  30.0    39.0             14.0            5.0           18.0
# 1         3.0  65.0    49.0              1.0           10.0            8.0
# 2         4.0  55.0    14.0              4.0            6.0           18.0
# 3         5.0  58.0    38.0             21.0            7.0            7.0
# 4         6.0  23.0    32.0             20.0            5.0            8.0
#
#   Subscription Type  Total Spend  Last Interaction  Churn Churn_Mapped  \
# 0          Standard        932.0              17.0    1.0        Churn
# 1             Basic        557.0               6.0    1.0        Churn
# 2             Basic        185.0               3.0    1.0        Churn
# 3          Standard        396.0              29.0    1.0        Churn
# 4             Basic        617.0              20.0    1.0        Churn
#
#   Age_Group  Gender_Female  Gender_Male  Contract Length_Annual  \
# ...

# %%
# dropping the customerID column as it is not needed for modeling
dataset = dataset.drop(columns=['CustomerID', 'Churn_Mapped', 'Age_Group'])

# %%
dataset.head()
# Out:
#     Age  Tenure  Usage Frequency  Support Calls  Payment Delay  Total Spend  \
# 0  30.0    39.0             14.0            5.0           18.0        932.0
# 1  65.0    49.0              1.0           10.0            8.0        557.0
# 2  55.0    14.0              4.0            6.0           18.0        185.0
# 3  58.0    38.0             21.0            7.0            7.0        396.0
# 4  23.0    32.0             20.0            5.0            8.0        617.0
#
#    Last Interaction  Churn  Gender_Female  Gender_Male  \
# 0              17.0    1.0              1            0
# 1               6.0    1.0              1            0
# 2               3.0    1.0              1            0
# 3              29.0    1.0              0            1
# 4              20.0    1.0              0            1
#
#    Contract Length_Annual  Contract Length_Monthly  Contract Length_Quarterly  \
# 0                       1                        0                          0
# ...

# %%
# removing original Subscription Type column after encoding
dataset = dataset.drop(columns=['Subscription Type'])
